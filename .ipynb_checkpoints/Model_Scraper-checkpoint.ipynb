# %%
# Important References Used for this Code
# http://automatetheboringstuff.com/chapter11/ 
# https://stackoverflow.com/questions/3368969/find-string-between-two-substrings

# %% [markdown]
# ## Packages

# %%
import webbrowser # package to open web browser pages
import bs4 # used to parse website data
import requests # used to pull source code
import re # used for string parsing/matching

# %% [markdown]
# ## Scraping for Each Skin's URLs

# %%
# Create beautiful soup object to examine the source code
res = requests.get('https://teemo.gg/model-viewer')
res.raise_for_status()
ModelSoup = bs4.BeautifulSoup(res.text)

# %%
# Functions for Scraping the URL and Name
def scrape_model_url(str):
    url_result = re.search("'id': '(.*)',", str)
    if url_result:
        url = url_result.group(1)
        return url
    else: 
        return "No Match"

def scrape_model_name(str):
    name_result = re.search("'name': \"(.*)\"", str)
    if name_result:
        name = name_result.group(1)
        return name
    else: 
        return "No Match"

# %%
# Get List of Skins/Chromas and the corresponding URL
skins_html = ModelSoup.findAll('script')
skins_champs = skins_html[9].getText() # contains the dictionary of champions and skins
skins_champs = skins_champs.split(';')
skins_champs.pop(0) # remove the first index which does not contain champ/skin info

# Create Dictionary of URL and Skin Name
skin_dict = {}
for skins_champ in skins_champs:
    skins = skins_champ.split("},{") # would split by ",", but some names have a comma
    for skin in skins:
        url = scrape_model_url(skin)
        name = scrape_model_name(skin)
        if url == "No Match" or name == "No Match":
            break
        else:
            skin_dict[url] = name
            prev_name = name
            prev_url = url
    if url == "No Match" or name == "No Match":
            print("Done Scraping Champion Skin Information, Last Skin is " + prev_name + " (" + prev_url + ")" )
            break

# View Keys,Values in Dictionary
# for k,v in skin_dict.items():
#     print(k,v)

print(skins_champs)
# Out:
# Done Scraping Champion Skin Information, Last Skin is Dragon Sorceress Zyra (zyra-4)
# ['\nchampion_skins[\'266\'] = [{\'id\': \'aatrox-0\', \'name\': "Default Aatrox"},{\'id\': \'aatrox-1\', \'name\': "Justicar Aatrox"},{\'id\': \'aatrox-2\', \'name\': "Mecha Aatrox Chroma 1"},{\'id\': \'aatrox-4\', \'name\': "Mecha Aatrox Chroma 2"},{\'id\': \'aatrox-5\', \'name\': "Mecha Aatrox Chroma 3"},{\'id\': \'aatrox-6\', \'name\': "Mecha Aatrox Chroma 4"},{\'id\': \'aatrox-3\', \'name\': "Sea Hunter Aatrox"},{\'id\': \'aatrox-7\', \'name\': "Blood Moon Aatrox"},{\'id\': \'aatrox-8\', \'name\': "Blood Moon Aatrox Prestige Edition"},{\'id\': \'aatrox-9\', \'name\': "Victorious Aatrox Chroma 1"},{\'id\': \'aatrox-10\', \'name\': "Victorious Aatrox Chroma 2"},null]', '\nchampion_skins[\'103\'] = [{\'id\': \'ahri-0\', \'name\': "Default Ahri"},{\'id\': \'ahri-1\', \'name\': "Dynasty Ahri"},{\'id\': \'ahri-2\', \'name\': "Midnight Ahri"},{\'id\': \'ahri-3\', \'name\': "Foxfire Ahri"},{\'id\': \'ahri-4\', \'name\': "Popstar Ahri Chroma 1"},{\'id\': \'ahri-8\', \'name\': "Popstar Ahri Chroma 2"},{\'id\': \'ahri-9\', \'name\': "Popstar Ahri Chroma 3"},{\'id\': \'ahri-10\', \'name\': "Popstar Ahri Chroma 4"},{\'id\': \'ahri-11\', \'name\': "Popstar Ahri Chroma 5"},{\'id\': \'ahri-12\', \'name\': "Popstar Ahri Chroma 6"},{\'id\': \'ahri-13\', \'name\': "Popstar Ahri Chroma 7"},{\'id\': \'ahri-5\', \'name\': "Challenger Ahri Chroma 1"},{\'id\': \'ahri-18\', \'name\': "Challenger Ahri Chroma 2"},{\'id\': \'ahri-6\', \'name\': "Academy Ahri"},{\'id\': \'ahri-7\', \'name\': "Arcade Ahri"},{\'id\': \'ahri-14\', \'name\': "Star Guardian Ahri"},{\'id\': \'ahri-15\', \'name\': "K/DA Ahri"},{\'id\': \'ahri-16\', \'name\': "K/DA Ahri Prestige Edition"},{\'id\': \'ahri-17\', \'name\': "Elderwood Ahri Chroma 1"},{\'id\': \'ahri-19\', \'name\': "Elderwood Ahri Chroma 2"},{\'id\': \'ahri-20\', \'name\': "Elderwood Ahri Chroma 3"},{\'id\': \'ahri-21\', \'name\': "Elderwood Ahri Chroma 4"},{\'id\': \'ahri-22\', \'name\': "Elderwood Ahri Chroma 5"},{\'id\': \'ahri-23\', \'name\': "Elderwood Ahri Chroma 6"},{\'id\': \'ahri-24\', \'name\': "Elderwood Ahri Chroma 7"},{\'id\': \'ahri-25\', \'name\': "Elderwood Ahri Chroma 8"},{\'id\': \'ahri-26\', \'name\': "Elderwood Ahri Chroma 9"},null]', '\nchampion_skins[\'84\'] = [{\'id\': \'akali-0\', \'name\': "Default Akali"},{\'id\': \'akali-1\', \'name\': "Stinger Akali"},{\'id\': \'akali-2\', \'name\': "Infernal Akali"},{\'id\': \'akali-3\', \'name\': "All-star Akali"},{\'id\': \'akali-4\', \'name\': "Nurse Akali"},{\'id\': \'akali-5\', \'name\': "Blood Moon Akali"},{\'id\': \'akali-6\', \'name\': "Silverfang Akali"},{\'id\': \'akali-7\', \'name\': "Headhunter Akali Chroma 1"},{\'id\': \'akali-10\', \'name\': "Headhunter Akali Chroma 2"},{\'id\': \'akali-11\', \'name\': "Headhunter Akali Chroma 3"},{\'id\': \'akali-12\', \'name\': "Headhunter Akali Chroma 4"},{\'id\': \'akali-8\', \'name\': "Sashimi Akali"},{\'id\': \'akali-9\', \'name\': "K/DA Akali"},{\'id\': \'akali-13\', \'name\': "K/DA Akali Prestige Edition"},{\'id\': \'akali-14\', \'name\': "PROJECT: Akali Chroma 1"},{\'id\': \'akali-16\', \'name\': "PROJECT: Akali Chroma 2"},{\'id\': \'akali-17\', \'name\': "PROJECT: Akali Chroma 3"},{\'id\': \'akali-18\', \'name\': "PROJECT: Akali Chroma 4"},{\'id\': \'akali-19\', \'name\': "PROJECT: Akali Chroma 5"},{\'id\': \'akali-20\', \'name\': "PROJECT: Akali Chroma 6"},{\'id\': \'akali-21\', \'name\': "PROJECT: Akali Chroma 7"},{\'id\': \'akali-22\', \'name\': "PROJECT: Akali Chroma 8"},{\'id\': \'akali-23\', \'name\': "PROJECT: Akali Chroma 9"},{\'id\': \'akali-24\', \'name\': "PROJECT: Akali Chroma 10"},{\'id\': \'akali-15\', \'name\': "True Damage Akali Chroma 1"},{\'id\': \'akali-25\', \'name\': "True Damage Akali Chroma 2"},{\'id\': \'akali-26\', \'name\': "True Damage Akali Chroma 3"},{\'id\': \'akali-27\', \'name\': "True Damage Akali Chroma 4"},{\'id\': \'akali-28\', \'name\': "True Damage Akali Chroma 5"},{\'id\': \'akali-29\', \'name\': "True Damage Akali Chroma 6"},{\'id\': \'akali-30\', \'name\ ...

# %% [markdown]
# ## Navigating to the Various Pages

# %%
#navigate to a specific champ's model viewer page
i = 0
for url, name in skin_dict.items():
    if i == 5:
        break
    i+=1
    full_url = 'https://teemo.gg/model-viewer?skinid=' + url + '&model-type=champions'
    print(name, full_url)
# Out:
# Default Aatrox https://teemo.gg/model-viewer?skinid=aatrox-0&model-type=champions
# Justicar Aatrox https://teemo.gg/model-viewer?skinid=aatrox-1&model-type=champions
# Mecha Aatrox Chroma 1 https://teemo.gg/model-viewer?skinid=aatrox-2&model-type=champions
# Mecha Aatrox Chroma 2 https://teemo.gg/model-viewer?skinid=aatrox-4&model-type=champions
# Mecha Aatrox Chroma 3 https://teemo.gg/model-viewer?skinid=aatrox-5&model-type=champions

# %%
import selenium
from selenium import webdriver

DRIVER = 'chromedriver'
driver = webdriver.Chrome(DRIVER)
driver.get('https://www.spotify.com')
screenshot = driver.save_screenshot('my_screenshot.png')
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1177                                          os.fspath(cwd) if cwd is not None else None,
# -> 1178                                          startupinfo)
#    1179             finally:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-41-583043350e7a> in <module>
#       3
#       4 DRIVER = 'chromedriver'
# ----> 5 driver = webdriver.Chrome(DRIVER)
#       6 driver.get('https://www.spotify.com')
#       7 screenshot = driver.save_screenshot('my_screenshot.png')
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      71             service_args=service_args,
#      72             log_path=service_log_path)
# ---> 73         self.service.start()
#      74
#      75         try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      81                 raise WebDriverException(
#      82                     "'%s' executable needs to be in PATH. %s" % (
# ---> 83                         os.path.basename(self.path), self.start_error_message)
#      84                 )
#      85             elif err.errno == errno.EACCES:
#
# WebDriverException: Message: 'chromedriver' executable needs to be in PATH. Please see https://sites.google.com/a/chromium.org/chromedriver/home
